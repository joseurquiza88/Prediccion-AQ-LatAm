# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import r2_score, mean_squared_error
import joblib
import os

# %%
import geopandas as gpd
gpd.show_versions()
# Out:
# SYSTEM INFO
# -----------
# python     : 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]
# executable : d:\Josefina\Proyectos\Tesis\code\07_PyCode\.venv\Scripts\python.exe
# machine    : Windows-10-10.0.19045-SP0
#
# GEOS, GDAL, PROJ INFO
# ---------------------
# GEOS       : 3.13.1
# GEOS lib   : None
# GDAL       : 3.11.4
# GDAL data dir: d:\Josefina\Proyectos\Tesis\code\07_PyCode\.venv\Lib\site-packages\pyogrio\gdal_data\
# PROJ       : 9.5.1
# PROJ data dir: d:\Josefina\Proyectos\Tesis\code\07_PyCode\.venv\Lib\site-packages\pyproj\proj_dir\share\proj
#
# PYTHON DEPENDENCIES
# -------------------
# geopandas  : 1.1.1
# numpy      : 2.3.5
# pandas     : 2.3.3
# pyproj     : 3.7.2
# shapely    : 2.1.2
# pyogrio    : 0.12.1
# geoalchemy2: None
# geopy      : None
# matplotlib : None
# mapclassify: None
# fiona      : None
# psycopg    : None
# psycopg2   : None
# pyarrow    : None
